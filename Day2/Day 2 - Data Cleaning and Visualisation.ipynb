# %% [markdown]
# ## Playing with Datasets

# %%
import pandas as pd

# %%
dataset = pd.read_csv('dataset/weather_dict.csv')

# %%
dataset.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  SeaLevelPressureIn  \
# 0  1/1/2016           38        23        52               30.03
# 1  1/2/2016           36        18        46               30.02
# 2  1/3/2016           40        21        47               29.86
# 3  1/4/2016           25         9        44               30.05
# 4  1/5/2016           20        -3        41               30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
dataset.shape
# Out:
# (31, 11)

# %%
dataset['Temperature'].max()
# Out:
# 50

# %%
# Finding the day with maximum temperature

dataset['EST'][dataset['Temperature']==50]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
dataset.head(12) # Verifiying with dataset -> At row 9
# Out:
#           EST  Temperature  DewPoint  Humidity  SeaLevelPressureIn  \
# 0    1/1/2016           38        23        52               30.03
# 1    1/2/2016           36        18        46               30.02
# 2    1/3/2016           40        21        47               29.86
# 3    1/4/2016           25         9        44               30.05
# 4    1/5/2016           20        -3        41               30.57
# 5    1/6/2016           33         4        35               30.50
# 6    1/7/2016           39        11        33               30.28
# 7    1/8/2016           39        29        64               30.20
# 8    1/9/2016           44        38        77               30.16
# 9   1/10/2016           50        46        71               29.59
# 10  1/11/2016           33         8        37               29.92
# 11  1/12/2016           35        15        53               29.85
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# ...

# %% [markdown]
# #### Finding Missing Values in a Dataset
#
# - isnull()
# - isna()

# %%
dataset.isnull()
# Out:
#       EST  Temperature  DewPoint  Humidity  SeaLevelPressureIn  \
# 0   False        False     False     False               False
# 1   False        False     False     False               False
# 2   False        False     False     False               False
# 3   False        False     False     False               False
# 4   False        False     False     False               False
# 5   False        False     False     False               False
# 6   False        False     False     False               False
# 7   False        False     False     False               False
# 8   False        False     False     False               False
# 9   False        False     False     False               False
# 10  False        False     False     False               False
# 11  False        False     False     False               False
# 12  False        False     False     False               False
# 13  False        False     False     False               False
# ...

# %%
# Using loc to get exact attributes with null values

dataset.loc[:,dataset.isnull().any()]
# Out:
#     WindSpeedMPH    Events
# 0            8.0       NaN
# 1            7.0       NaN
# 2            8.0       NaN
# 3            9.0       NaN
# 4            5.0       NaN
# 5            4.0       NaN
# 6            2.0       NaN
# 7            4.0       NaN
# 8            8.0      Rain
# 9            NaN      Rain
# 10           NaN       NaN
# 11           6.0       NaN
# 12          10.0       NaN
# 13           5.0       NaN
# 14           5.0       NaN
# 15           7.0      Rain
# 16           6.0  Fog-Snow
# 17          12.0      Snow
# 18          11.0       NaN
# 19           6.0       NaN
# 20           6.0       NaN
# 21           NaN      Snow
# 22          16.0  Fog-Snow
# 23           6.0      Snow
# 24           3.0       NaN
# 25           7.0       NaN
# 26           7.0      Rain
# 27           5.0       NaN
# 28           8.0       NaN
# 29           7.0       NaN
# 30           5.0       NaN

# %% [markdown]
# #### Dropping columns
# - Use drop()
#
# #### Other methods to handle missing values
# - fillna()
# - interpolate()
# - dropna()

# %%
## Using drop to remove columns or rows -> Specifying headers

final_data = dataset.drop(['VisibilityMiles','PrecipitationIn','SeaLevelPressureIn','WindSpeedMPH','CloudCover','Events','WindDirDegrees'],axis=1)

# %%
final_data
# Out:
#           EST  Temperature  DewPoint  Humidity
# 0    1/1/2016           38        23        52
# 1    1/2/2016           36        18        46
# 2    1/3/2016           40        21        47
# 3    1/4/2016           25         9        44
# 4    1/5/2016           20        -3        41
# 5    1/6/2016           33         4        35
# 6    1/7/2016           39        11        33
# 7    1/8/2016           39        29        64
# 8    1/9/2016           44        38        77
# 9   1/10/2016           50        46        71
# 10  1/11/2016           33         8        37
# 11  1/12/2016           35        15        53
# 12  1/13/2016           26         4        42
# 13  1/14/2016           30        12        47
# 14  1/15/2016           43        31        62
# 15  1/16/2016           47        37        70
# 16  1/17/2016           36        23        66
# 17  1/18/2016           25         6        53
# 18  1/19/2016           22         3        42
# ...

# %%
final_data.Humidity.mean()
# Out:
# 51.67741935483871

# %% [markdown]
# ### Data Visualisation
#
# #### 1. Using matplotloib
# - [Reference](https://matplotlib.org/)

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y,color='green', marker='o', linestyle='dashed')

# %%
final_data.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 2. Seaborn

# %%
## Finding Correlation Matrix - Using Seaborn


import seaborn as sns

# %%
flights = sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.heatmap(flights.corr(), annot=True )
# Out:
# <AxesSubplot:>
