# %%
#Importing Dependancies
import pandas as pd
import numpy as np
import sklearn 
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from matplotlib import style

# %%
student_dataset = pd.read_csv('student-mat.csv',sep=';')
student_dataset = student_dataset[['G1','G2','G3','failures','absences']]
print(student_dataset)
# Out:
#      G1  G2  G3  failures  absences
# 0     5   6   6         0         6
# 1     5   5   6         0         4
# 2     7   8  10         3        10
# 3    15  14  15         0         2
# 4     6  10  10         0         4
# ..   ..  ..  ..       ...       ...
# 390   9   9   9         2        11
# 391  14  16  16         0         3
# 392  10   8   7         3         3
# 393  11  12  10         0         0
# 394   8   9   9         0         5
#
# [395 rows x 5 columns]

# %%
predict = "G3"
X = np.array(student_dataset.drop([predict],1))
y = np.array(student_dataset[predict])
# Out:
# C:\Users\DarkGamerX100\.conda\envs\ML\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X , y , test_size= 0.1)
Ultron = linear_model.LinearRegression()
Ultron.fit(x_train,y_train)
accuracy = Ultron.score(x_test,y_test)
print("ULTRON'S Accuracy at "+str(accuracy*100)+"%")
# Out:
# ULTRON'S Accuracy at 92.52460847853297%

# %%
print("Coefficients : ",Ultron.coef_)
print("Intercept : ",Ultron.intercept_)
# Out:
# Coefficients :  [ 0.13345397  0.98951629 -0.25781361  0.04397394]
# Intercept :  -1.82013930749131

# %%
predictions = Ultron.predict(x_test)
for i in range(len(predictions)):
    print("ULTRON's Predicted G3 - ",predictions[i],". Actual G3 - ",y_test[i],".")
# Out:
# ULTRON's Predicted G3 -  10.83881901663452 . Actual G3 -  11 .
# ULTRON's Predicted G3 -  12.911928112089559 . Actual G3 -  14 .
# ULTRON's Predicted G3 -  8.550436706492983 . Actual G3 -  10 .
# ULTRON's Predicted G3 -  18.214365399087797 . Actual G3 -  18 .
# ULTRON's Predicted G3 -  12.271139004739158 . Actual G3 -  12 .
# ULTRON's Predicted G3 -  8.595942802449962 . Actual G3 -  11 .
# ULTRON's Predicted G3 -  15.553634082925836 . Actual G3 -  16 .
# ULTRON's Predicted G3 -  10.532533610034061 . Actual G3 -  12 .
# ULTRON's Predicted G3 -  3.670352381933089 . Actual G3 -  0 .
# ULTRON's Predicted G3 -  11.69947781308332 . Actual G3 -  12 .
# ULTRON's Predicted G3 -  16.101878840224977 . Actual G3 -  18 .
# ULTRON's Predicted G3 -  8.507994926810602 . Actual G3 -  9 .
# ULTRON's Predicted G3 -  7.515414316902763 . Actual G3 -  6 .
# ULTRON's Predicted G3 -  14.077340157001519 . Actual G3 -  14 .
# ULTRON's Predicted G3 -  6.789011746037534 . Actual G3 -  7 .
# ULTRON's Predicted G3 -  -1.8019506377456262 . Actual G3 -  0 .
# ULTRON's Predicted G3 -  11.522049903667302 . Actual G3 -  10 .
# ULTRON's Predicted G3 -  10.574975389716442 . Actual G3 -  9 .
# ULTRON's Predicted G3 -  11.724426405577315 . Actual G3 -  13 .
# ULTRON's Predicted G3 -  6.304496176033824 . Actual G3 -  7 .
# ULTRON's Predicted G3 -  -0.8859615063169386 . Actual G3 -  0 .
# ULTRON's Predicted G3 -  16.280838907778296 . Actual G3 -  17 .
# ULTRON's Predicted G3 -  9.364057248847503 . Actual G3 -  10 .
# ULTRON's Predicted G3 -  16.32174852932338 . Actual G3 -  15 .
# ULTRON's Predicted G3 -  10.75393545726976 . Actual G3 -  12 .
# ULTRON's Predicted G3 -  16.01239880644832 . Actual G3 -  16 .
# ULTRON's Predicted G3 -  9.497511220443842 . Actual G3 -  10 .
# ULTRON's Predicted G3 -  15.024414670952378 . Actual G3 -  15 .
# ULTRON's Predicted G3 -  10.884325112591501 . Actual G3 -  10 .
# ULTRON's Predicted G3 -  12.016389712693922 . Actual G3 -  12 .
# ULTRON's Predicted G3 -  15.112362546591736 . Actual G3 -  14 .
# ULTRON's Predicted G3 -  9.009201430015466 . Actual G3 -  11 .
# ULTRON's Predicted G3 -  19.692191483149415 . Actual G3 -  20 .
# ULTRON's Predicted G3 -  9.409563344804482 . Actual G3 -  9 .
# ULTRON's Predicted G3 -  10.799441553226739 . Actual G3 -  10 .
# ULTRON's Predicted G3 -  13.896642545930014 . Actual G3 -  11 .
# ULTRON's Predicted G3 -  5.870786816435269 . Actual G3 -  7 .
# ULTRON's Predicted G3 -  9.364057248847503 . Actual G3 -  9 .
# ULTRON's Predicted G3 -  18.259871495044777 . Actual G3 -  18 .
# ULTRON's Predicted G3 -  15.02288251281508 . Actual G3 -  16 .

# %%
style.use("ggplot")
plt.scatter(student_dataset['absences'],student_dataset['G3'])
plt.xlabel('Absences')
plt.ylabel('Final G3')
plt.show()
