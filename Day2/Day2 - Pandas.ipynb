# %%
import pandas as pd

# %%
# Taking a dataset

dataset = pd.read_csv('dataset/weather_dict.csv')

# %%
dataset.head(25)
dataset.shape
# Out:
# (31, 11)

# %%
dataset['EST'][dataset['Temperature']==50]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
Nullset

# %%
dataset.isnull()
dataset.isna()
# Out:
#       EST  Temperature  DewPoint  Humidity  SeaLevelPressureIn  \
# 0   False        False     False     False               False
# 1   False        False     False     False               False
# 2   False        False     False     False               False
# 3   False        False     False     False               False
# 4   False        False     False     False               False
# 5   False        False     False     False               False
# 6   False        False     False     False               False
# 7   False        False     False     False               False
# 8   False        False     False     False               False
# 9   False        False     False     False               False
# 10  False        False     False     False               False
# 11  False        False     False     False               False
# 12  False        False     False     False               False
# 13  False        False     False     False               False
# ...

# %%
dataset.loc[:, dataset.isnull().any()]  ## Locate
# Out:
#     WindSpeedMPH    Events
# 0            8.0       NaN
# 1            7.0       NaN
# 2            8.0       NaN
# 3            9.0       NaN
# 4            5.0       NaN
# 5            4.0       NaN
# 6            2.0       NaN
# 7            4.0       NaN
# 8            8.0      Rain
# 9            NaN      Rain
# 10           NaN       NaN
# 11           6.0       NaN
# 12          10.0       NaN
# 13           5.0       NaN
# 14           5.0       NaN
# 15           7.0      Rain
# 16           6.0  Fog-Snow
# 17          12.0      Snow
# 18          11.0       NaN
# 19           6.0       NaN
# 20           6.0       NaN
# 21           NaN      Snow
# 22          16.0  Fog-Snow
# 23           6.0      Snow
# 24           3.0       NaN
# 25           7.0       NaN
# 26           7.0      Rain
# 27           5.0       NaN
# 28           8.0       NaN
# 29           7.0       NaN
# 30           5.0       NaN

# %%
final_data = data_final.drop(['VisibilityMiles','PrecipitationIn','SeaLevelPressureIn','WindSpeedMPH','CloudCover','Events','WindDirDegrees'], axis = 1)

# %%
type(final_data)

type(final_data.EST)
final_data
# Out:
#           EST  Temperature  DewPoint  Humidity
# 1    1/2/2016           36        18        46
# 2    1/3/2016           40        21        47
# 3    1/4/2016           25         9        44
# 4    1/5/2016           20        -3        41
# 5    1/6/2016           33         4        35
# 6    1/7/2016           39        11        33
# 7    1/8/2016           39        29        64
# 8    1/9/2016           44        38        77
# 9   1/10/2016           50        46        71
# 10  1/11/2016           33         8        37

# %%
mean_humidity = data_final['Humidity'].mean()
mean_humidity
# Out:
# 49.5

# %%
mean_temperature = data_final['Temperature'].mean()
mean_temperature
# Out:
# 35.9

# %%
mean_dewpoint = data_final['DewPoint'].mean()
mean_dewpoint
# Out:
# 18.1

# %%
mean_parameters = pd.DataFrame({'mean_humidity':[49.5], 'mean_temperature':[35.9],'mean_dewpoint':[18.1]})
mean_parameters.insert(0,'Month',['January'])

# %%
mean_parameters
# Out:
#      Month  mean_humidity  mean_temperature  mean_dewpoint
# 0  January           49.5              35.9           18.1

# %%
entry1 = {'Month':'February','mean_humidity':39.5, 'mean_temperature':27.9,'mean_dewpoint':16.3} 
mean_parameters.append(entry1, ignore_index=True)
# Out:
#       Month  mean_humidity  mean_temperature  mean_dewpoint
# 0   January           49.5              35.9           18.1
# 1  February           39.5              27.9           16.3

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x,y,color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12)

# %%
# Out:
# (array([2., 2., 0., 0.]),
#  array([ 2,  4,  6,  8, 10]),
#  <BarContainer object of 4 artists>)

# %%
chat_content = final_data.to_numpy()

# %%
final_data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-97-a84c0541e888> in <module>
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'
