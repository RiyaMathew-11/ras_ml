# %%
#Importing Dependancies
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

# %%
cars_dataset = pd.read_csv('cars.csv',sep=',')
print(cars_dataset.head())
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %%
le = preprocessing.LabelEncoder()
buying = le.fit_transform(list(cars_dataset['buying']))
maint = le.fit_transform(list(cars_dataset['maint']))
door = le.fit_transform(list(cars_dataset['door']))
persons = le.fit_transform(list(cars_dataset['persons']))
lug_boot = le.fit_transform(list(cars_dataset['lug_boot']))
safety = le.fit_transform(list(cars_dataset['safety']))
cls = le.fit_transform(list(cars_dataset['class']))

# %%
X = list(zip(buying,maint,door,persons,lug_boot,safety))
y = list(cls)
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)
Friday = KNeighborsClassifier(n_neighbors=9)
Friday.fit(x_train, y_train)
acc = model.score(x_test, y_test)
print("Friday at",(acc*100),'% Accuracy.')
# Out:
# Friday at 95.37572254335261 % Accuracy.

# %%
predictions = Friday.predict(x_test)
        #   0      1      2     3
decoder = ['unacc','acc','good','vgood']
for i in range(len(predictions)):
    print("Friday Predicted : ",decoder[predictions[i]],"Actual Class : ",decoder[y_test[i]])
# Out:
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  acc Actual Class :  acc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  acc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  acc Actual Class :  acc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  unacc Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  acc Actual Class :  acc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  acc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  acc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  vgood Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  unacc Actual Class :  vgood
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  unacc Actual Class :  unacc
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
# Friday Predicted :  good Actual Class :  good
